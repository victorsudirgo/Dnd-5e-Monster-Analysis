# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data from DnD 5e Monsters
# from www.aidedd.org \
# link : https://www.kaggle.com/datasets/mrpantherson/dnd-5e-monsters

# %%
dnd = pd.read_csv('monsters.csv', index_col=False)

# %%
dnd = dnd.drop(columns=dnd.columns[0])

# %%
dnd.head()
# Out:
#                         _id               index                name    size  \
# 0  5f2329ad0b1bb138c59411ee             aboleth             Aboleth   Large
# 1  5f2329ad0b1bb138c59411ef             acolyte             Acolyte  Medium
# 2  5f2329ad0b1bb138c59411f1  adult-black-dragon  Adult Black Dragon    Huge
# 3  5f2329ad0b1bb138c59411f0   adult-blue-dragon   Adult Blue Dragon    Huge
# 4  5f2329ad0b1bb138c59411f2  adult-brass-dragon  Adult Brass Dragon    Huge
#
#          type   subtype      alignment  armor_class  hit_points hit_dice  ...  \
# 0  aberration       NaN    lawful evil           17         135    18d10  ...
# 1    humanoid  any race  any alignment           10           9      2d8  ...
# 2      dragon       NaN   chaotic evil           19         195    17d12  ...
# 3      dragon       NaN    lawful evil           19         225    18d12  ...
# 4      dragon       NaN   chaotic good           18         172    15d12  ...
#
# ...

# %%
dnd.describe()
# Out:
#        armor_class  hit_points    strength   dexterity  constitution  \
# count   322.000000  322.000000  322.000000  322.000000    322.000000
# mean     14.031056   81.291925   15.161491   12.624224     15.080745
# std       3.256285   99.425430    6.736612    3.202185      4.506105
# min       5.000000    1.000000    1.000000    1.000000      8.000000
# 25%      12.000000   18.250000   11.000000   10.000000     12.000000
# 50%      13.000000   45.000000   16.000000   13.000000     14.000000
# 75%      17.000000  114.000000   19.000000   15.000000     18.000000
# max      25.000000  676.000000   30.000000   28.000000     30.000000
#
#        intelligence      wisdom    charisma  challenge_rating
# count    322.000000  322.000000  322.000000        322.000000
# mean       7.754658   11.686335    9.683230          4.543090
# std        5.704460    2.934020    5.789584          5.892224
# min        1.000000    3.000000    1.000000          0.000000
# ...

# %%
dnd.loc[:,'size'].value_counts()
# Out:
# Medium        126
# Large         103
# Huge           32
# Tiny           24
# Small          22
# Gargantuan     15
# Name: size, dtype: int64

# %%
#Count of Monster Size with countplot
ax = sns.countplot(x=dnd["size"], order=dnd['size'].value_counts().index, palette= 'crest_r')
ax.set(xlabel='Size', ylabel='Count')
plt.show()

# %% [markdown]
# # Insight:
# - Medium size monster is the greatest number than any other size
# - Large size monster also have many number
# - Gargantuan being the biggest have the least number of monsters

# %%
#Count of Monster Size with barplot
ax = sns.barplot(d.values, d.index, palette='crest_r')
ax.set(ylabel='Size', xlabel='Count')
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Median of Monster Types Armor Class
typemedian = dnd.groupby('type')['armor_class'].median().sort_values(ascending=False)
ax = sns.barplot(typemedian.values, typemedian.index,palette='crest_r')
ax.set(xlabel='Median of Armor Class', ylabel='Type')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 0, 'Median of Armor Class'), Text(0, 0.5, 'Type')]

# %%
#Median of Monster Types CR Rating
typemedian = dnd.groupby('type')['challenge_rating'].median().sort_values(ascending=False)
ax = sns.barplot(typemedian.values, typemedian.index,palette='crest_r')
ax.set(xlabel='Median of CR Rating', ylabel='Type')
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Insight:
# - Dragon have the biggest median of CR
# - Beast have the smallest median of CR

# %%
#Top 5 Dragon based on Challange Rating
dragoncr = dnd.loc[dnd.type == 'dragon', ['name','challenge_rating']].sort_values(by=['challenge_rating'], ascending=False)
dragoncr = dragoncr.head(5).reset_index(drop=True)
dragoncr
# Out:
#                     name  challenge_rating
# 0    Ancient Gold Dragon              24.0
# 1     Ancient Red Dragon              24.0
# 2  Ancient Silver Dragon              23.0
# 3    Ancient Blue Dragon              23.0
# 4  Ancient Bronze Dragon              22.0

# %% [markdown]
# # Insight:
# - All of the dragon with the biggest CR is Ancient
# - All CR is above 20

# %%
#alignment count

#remove 'any' and '50%'
x = dnd[~dnd['alignment'].str.contains('any')]
x = x[~x['alignment'].str.contains('50%')]


ax = sns.countplot(x=x["alignment"], order=x['alignment'].value_counts().index, palette= 'crest_r')
ax.set(xlabel='Alignment', ylabel='Count')

plt.xticks(rotation=30)
plt.show()

# %%
#stats correlation
matrix = np.triu(dnd.corr())
dataplot = sns.heatmap(dnd.corr(), cmap="rocket_r", annot=True, mask=matrix)

# %% [markdown]
# # Insight:
# - Constitution have a strong correlation with HP and Strength
# - Dex have weak correlations to all of the other indicator
# - Intelligence have a very strong correlation with Charisma
# - CR and HP have the biggest correlation of 94%
